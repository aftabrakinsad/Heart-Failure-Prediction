# %%
import time
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Multiply, Layer
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, auc

# %%
X_train = pd.read_csv('/content/X_train_final.csv').values
y_train = pd.read_csv('/content/y_train_final.csv').values
X_val = pd.read_csv('/content/X_val_processed.csv').values
y_val = pd.read_csv('/content/y_val_processed.csv').values
X_test = pd.read_csv('/content/X_test_processed.csv').values
y_test = pd.read_csv('/content/y_test_processed.csv').values

y_train = y_train.astype(np.float32)
y_val = y_val.astype(np.float32)
y_test = y_test.astype(np.float32)

X_train_combined = np.concatenate((X_train, X_val), axis=0)
y_train_combined = np.concatenate((y_train, y_val), axis=0)

input_dim = X_train.shape[1]

best_params = {
    'initial_dense_units': 32,
    'num_dense_layers_after_attention': 3,
    'dense_units_L1': 64,
    'dense_units_L2': 64,
    'dense_units_L3': 16,
    'attention_transform_units': 64,
    'learning_rate': 0.0073866678565409506,
    'batch_size': 32,
    'optimizer': 'rmsprop',
    'dropout_rate': 0.25,
}

# %%
class FeatureAttentionLayer(Layer):
    def __init__(self, attention_transform_units=None, **kwargs):
        super(FeatureAttentionLayer, self).__init__(**kwargs)
        self.attention_transform_units = attention_transform_units

    def build(self, input_shape):
        if self.attention_transform_units is None:
            self.attention_transform_units = input_shape[-1]
        self.attention_transform_layer = Dense(self.attention_transform_units, activation='tanh', use_bias=True, name='attention_transform')
        self.attention_weights_layer = Dense(input_shape[-1], activation='softmax', use_bias=False, name='attention_weights')
        super(FeatureAttentionLayer, self).build(input_shape)

    def call(self, inputs):
        transformed_inputs = self.attention_transform_layer(inputs)
        attention_weights = self.attention_weights_layer(transformed_inputs)
        weighted_inputs = Multiply()([inputs, attention_weights])
        return weighted_inputs

    def get_config(self):
        config = super(FeatureAttentionLayer, self).get_config()
        config.update({'attention_transform_units': self.attention_transform_units})
        return config

# %%
def build_1_dense_layer_model(input_dim, params):
    tf.keras.backend.clear_session()

    initial_dense_units = params['initial_dense_units']
    dropout_rate = params['dropout_rate']
    learning_rate = params['learning_rate']

    optimizer = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)

    inputs = Input(shape=(input_dim,), name='Input')

    x = Dense(initial_dense_units, activation='relu', name='initial_dense')(inputs)
    x = Dropout(dropout_rate, name='initial_dropout')(x)

    x = FeatureAttentionLayer(attention_transform_units=params['attention_transform_units'], name='feature_attention_layer')(x)

    x = Dense(params['dense_units_L1'], activation='relu', name='dense_L1')(x)
    x = Dropout(dropout_rate, name='dropout_L1')(x)

    outputs = Dense(1, activation='sigmoid', name='Output')(x)

    model = Model(inputs=inputs, outputs=outputs, name='MLP_1_Dense_Layer')
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy', tf.keras.metrics.AUC()])

    return model

# %%
ablated_model = build_1_dense_layer_model(input_dim, best_params)
ablated_model.summary()
# Out:
# Model: "MLP_1_Dense_Layer"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ initial_dense (Dense)           │ (None, 32)             │           416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ initial_dropout (Dropout)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ feature_attention_layer         │ (None, 32)             │         4,160 │
# │ (FeatureAttentionLayer)         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_L1 (Dense)                │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_L1 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,753 (26.38 KB)
#  Trainable params: 6,753 (26.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6, mode='min')
]

# %%
ablated_model.fit(
    X_train_combined, y_train_combined,
    validation_split=0.1,
    epochs=200,
    batch_size=best_params['batch_size'],
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6778 - auc: 0.7477 - loss: 0.5903 - val_accuracy: 0.8281 - val_auc: 0.8829 - val_loss: 0.3690 - learning_rate: 0.0074
# Epoch 2/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8121 - auc: 0.8877 - loss: 0.4184 - val_accuracy: 0.8203 - val_auc: 0.9024 - val_loss: 0.3873 - learning_rate: 0.0074
# Epoch 3/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8458 - auc: 0.9149 - loss: 0.3670 - val_accuracy: 0.8594 - val_auc: 0.9144 - val_loss: 0.3639 - learning_rate: 0.0074
# Epoch 4/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8468 - auc: 0.9169 - loss: 0.3708 - val_accuracy: 0.8594 - val_auc: 0.9252 - val_loss: 0.3101 - learning_rate: 0.0074
# Epoch 5/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8775 - auc: 0.9308 - loss: 0.3366 - val_accuracy: 0.8359 - val_auc: 0.9338 - val_loss: 0.3413 - learning_rate: 0.0074
# Epoch 6/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8802 - auc: 0.9466 - loss: 0.2946 - val_accuracy: 0.8750 - val_auc: 0.9541 - val_loss: 0.2905 - learning_rate: 0.0074
# Epoch 7/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8709 - auc: 0.9469 - loss: 0.2962 - val_accuracy: 0.8750 - val_auc: 0.9589 - val_loss: 0.2816 - learning_rate: 0.0074
# Epoch 8/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8734 - auc: 0.9431 - loss: 0.3047 - val_accuracy: 0.8906 - val_auc: 0.9549 - val_loss: 0.2709 - learning_rate: 0.0074
# Epoch 9/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8870 - auc: 0.9615 - loss: 0.2500 - val_accuracy: 0.8906 - val_auc: 0.9613 - val_loss: 0.2433 - learning_rate: 0.0074
# Epoch 10/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9096 - auc: 0.9650 - loss: 0.2371 - val_accuracy: 0.8672 - val_auc: 0.9593 - val_loss: 0.2645 - learning_rate: 0.0074
# Epoch 11/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8925 - auc: 0.9675 - loss: 0.2285 - val_accuracy: 0.9219 - val_auc: 0.9652 - val_loss: 0.2567 - learning_rate: 0.0074
# Epoch 12/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9004 - auc: 0.9654 - loss: 0.2374 - val_accuracy: 0.9141 - val_auc: 0.9667 - val_loss: 0.2068 - learning_rate: 0.0074
# Epoch 13/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8956 - auc: 0.9642 - loss: 0.2411 - val_accuracy: 0.9297 - val_auc: 0.9746 - val_loss: 0.2049 - learning_rate: 0.0074
# Epoch 14/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8986 - auc: 0.9679 - loss: 0.2220 - val_accuracy: 0.9219 - val_auc: 0.9672 - val_loss: 0.2160 - learning_rate: 0.0074
# Epoch 15/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9245 - auc: 0.9737 - loss: 0.2051 - val_accuracy: 0.8984 - val_auc: 0.9521 - val_loss: 0.2557 - learning_rate: 0.0074
# Epoch 16/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - auc: 0.9676 - loss: 0.2333 - val_accuracy: 0.8984 - val_auc: 0.9623 - val_loss: 0.2260 - learning_rate: 0.0074
# Epoch 17/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9051 - auc: 0.9697 - loss: 0.2264 - val_accuracy: 0.8828 - val_auc: 0.9578 - val_loss: 0.2513 - learning_rate: 0.0074
# Epoch 18/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9124 - auc: 0.9737 - loss: 0.2072 - val_accuracy: 0.9062 - val_auc: 0.9651 - val_loss: 0.2145 - learning_rate: 0.0074
# Epoch 19/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8980 - auc: 0.9663 - loss: 0.2411 - val_accuracy: 0.8984 - val_auc: 0.9647 - val_loss: 0.2125 - learning_rate: 0.0074
# Epoch 20/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9026 - auc: 0.9681 - loss: 0.2258 - val_accuracy: 0.9375 - val_auc: 0.9802 - val_loss: 0.1881 - learning_rate: 0.0074
# Epoch 21/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9113 - auc: 0.9672 - loss: 0.2377 - val_accuracy: 0.9141 - val_auc: 0.9736 - val_loss: 0.1974 - learning_rate: 0.0074
# Epoch 22/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9090 - auc: 0.9744 - loss: 0.2035 - val_accuracy: 0.9141 - val_auc: 0.9651 - val_loss: 0.2336 - learning_rate: 0.0074
# Epoch 23/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9102 - auc: 0.9682 - loss: 0.2285 - val_accuracy: 0.8984 - val_auc: 0.9644 - val_loss: 0.2084 - learning_rate: 0.0074
# Epoch 24/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9173 - auc: 0.9761 - loss: 0.1955 - val_accuracy: 0.8984 - val_auc: 0.9589 - val_loss: 0.2425 - learning_rate: 0.0074
# Epoch 25/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9008 - auc: 0.9720 - loss: 0.2093 - val_accuracy: 0.8984 - val_auc: 0.9611 - val_loss: 0.2293 - learning_rate: 0.0074
# Epoch 26/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9192 - auc: 0.9779 - loss: 0.1788 - val_accuracy: 0.9062 - val_auc: 0.9628 - val_loss: 0.2103 - learning_rate: 0.0074
# Epoch 27/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8990 - auc: 0.9619 - loss: 0.2651 - val_accuracy: 0.9062 - val_auc: 0.9641 - val_loss: 0.2188 - learning_rate: 0.0074
# Epoch 28/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9226 - auc: 0.9800 - loss: 0.1776 - val_accuracy: 0.8984 - val_auc: 0.9573 - val_loss: 0.2363 - learning_rate: 0.0074
# Epoch 29/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9125 - auc: 0.9708 - loss: 0.2067 - val_accuracy: 0.8672 - val_auc: 0.9546 - val_loss: 0.2783 - learning_rate: 0.0074
# Epoch 30/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9161 - auc: 0.9790 - loss: 0.1811 - val_accuracy: 0.9141 - val_auc: 0.9608 - val_loss: 0.2243 - learning_rate: 0.0074

# %%
test_loss, test_accuracy, test_auc = ablated_model.evaluate(X_test, y_test, verbose=0)
y_pred_proba = ablated_model.predict(X_test).ravel()
y_pred_binary = (y_pred_proba > 0.5).astype(int)
precision = precision_score(y_test, y_pred_binary)
recall = recall_score(y_test, y_pred_binary)
f1 = f1_score(y_test, y_pred_binary)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
trainable_count = np.sum([K.count_params(w) for w in ablated_model.trainable_weights])
non_trainable_count = np.sum([K.count_params(w) for w in ablated_model.non_trainable_weights])
total_parameters = trainable_count + non_trainable_count

# %%
start_time = time.time()
ablated_model.predict(X_test, batch_size=best_params['batch_size'])
end_time = time.time()
inference_time_batch = (end_time - start_time)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
print("Ablated Model: 1 Dense Layer after Attention")
print(f"Accuracy: {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"AUC: {test_auc:.4f}")
print(f"Parameters: {total_parameters}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Inference Time (s/batch): {inference_time_batch:.4f}")
# Out:
# Ablated Model: 1 Dense Layer after Attention
# Accuracy: 0.9146
# Precision: 0.8250
# Recall: 0.8250
# F1-Score: 0.8250
# AUC: 0.9296
# Parameters: 6753.0
# Test Loss: 0.2624
# Inference Time (s/batch): 0.1008
